# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv("C:/Users/miguel.postigo/Desktop/carpeta/programacion/python/linkedin/esencial/base_datos_2008.csv")
#[]
df.dropna(inplace = True, subset =["ArrDelay","DepDelay","Distance","AirTime"])
#ajusto el tamaño del gráfico para que sea mas facil visualizarlo
sns.set(rc = {'figure.figsize':(15,10)})

# %%
df2 = df[df["Origin"].isin(["ATL","HOU","IND"])].sample(frac = 1).head(1000)

sns.jointplot(df2["DepDelay"],df2["ArrDelay"])
# Out:
# C:\Users\miguel.postigo\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df3 = df2[np.abs(df2["DepDelay"])<40]
df3 = df3[np.abs(df3["ArrDelay"])<40]

# %%
sns.jointplot(df3["DepDelay"],df3["ArrDelay"],kind = "hex")
# Out:
# C:\Users\miguel.postigo\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot(df3["DepDelay"],df3["ArrDelay"],kind = "kde")
# Out:
# C:\Users\miguel.postigo\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
gb_df = pd.DataFrame(df2.groupby(["Origin","Month"],as_index = False)["DepDelay"].mean())
gb_df.head()
# Out:
#   Origin  Month   DepDelay
# 0    ATL      1  14.338710
# 1    ATL      2  17.854839
# 2    ATL      3   9.268657
# 3    ATL      4   5.608696
# 4    ATL      5   2.984127

# %%
data = gb_df.pivot("Month","Origin","DepDelay")
data
# Out:
# Origin        ATL        HOU        IND
# Month
# 1       14.338710  15.375000  -1.900000
# 2       17.854839  24.600000  26.500000
# 3        9.268657  44.833333   3.000000
# 4        5.608696  12.166667  -1.000000
# 5        2.984127   6.625000   4.777778
# 6       14.750000  49.571429  20.250000
# 7       17.453333   3.714286   7.750000
# 8       15.123077   0.928571  -6.571429
# 9        0.583333   0.000000   9.111111
# 10       2.559322   4.181818  10.000000
# 11      16.378049   3.666667  -1.400000
# 12      19.233333  26.769231   1.857143

# %%
sns.set(rc = {'figure.figsize':(15,8)})
sns.heatmap(data = data, annot = True, linewidths = .5)
# Out:
# <AxesSubplot:xlabel='Origin', ylabel='Month'>
